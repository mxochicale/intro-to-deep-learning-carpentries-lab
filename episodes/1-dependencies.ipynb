# %%
# !pip install "numpy<2.0" --quiet #NumPy version incompatibility problem 
#the environment has NumPy 2.4.4 installed, but many packages (TensorFlow, SciPy, pandas) were compiled with NumPy 1.x and aren't yet compatible with NumPy 2.x.
# !pip install tensorflow --quiet
# !pip install seaborn --quiet
# Out:
#   WARNING: The scripts f2py and numpy-config are installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts saved_model_cli, tf_upgrade_v2, tflite_convert and toco are installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas 2.1.4 requires numpy<2,>=1.23.2; python_version == "3.11", but you have numpy 2.4.4 which is incompatible.
# scikit-learn 1.3.2 requires numpy<2.0,>=1.17.3, but you have numpy 2.4.4 which is incompatible.
# scipy 1.11.3 requires numpy<1.28.0,>=1.21.6, but you have numpy 2.4.4 which is incompatible.
#   WARNING: The script f2py is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import tensorflow
import seaborn
import sklearn
print(tensorflow.__version__)
print(seaborn.__version__)
print(sklearn.__version__)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777748503.635632     457 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1777748503.698120     457 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777748505.599410     457 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2.21.0
# 0.13.2
# 1.3.2
